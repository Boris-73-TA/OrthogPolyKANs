# %% [markdown]
# ## Fibonacci-KAN for MNIST

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import numpy as np
from FibonacciKANLayer import FibonacciKANLayer

# %%
# Construct a FibonacciKAN for MNIST
class MNISTFibonacciKAN(nn.Module):
    def __init__(self):
        super(MNISTFibonacciKAN, self).__init__()
        self.fibonaccikan1 = FibonacciKANLayer(28*28, 32, 4)
        self.ln1 = nn.LayerNorm(32) # To avoid gradient vanishing caused by tanh
        self.fibonaccikan2 = FibonacciKANLayer(32, 16, 4)
        self.ln2 = nn.LayerNorm(16)
        self.fibonaccikan3 = FibonacciKANLayer(16, 10, 4)

    def forward(self, x):
        x = x.view(-1, 28*28)  # Flatten the images
        x = self.fibonaccikan1(x)
        x = self.ln1(x)
        x = self.fibonaccikan2(x)
        x = self.ln2(x)
        x = self.fibonaccikan3(x)
        return x

# %%
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1024, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = MNISTFibonacciKAN().to(device)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total trainable parameters: {total_params}")

criterion = nn.CrossEntropyLoss()

# LBFGS is really slow
# optimizer = optim.LBFGS(model.parameters(), lr=0.01)
# Adam works with very low lr
optimizer = optim.Adam(model.parameters(), lr=0.0002)

def train(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    correct = 0
    
    for idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        if isinstance(optimizer, optim.LBFGS):
            def closure():
                optimizer.zero_grad()
                output = model(data)
                loss = criterion(output, target)
                loss.backward()
                return loss
            loss = optimizer.step(closure)
        else:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            loss = loss.item()
            
        total_loss += loss
        
    return total_loss / len(train_loader)

def validate(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    return total_loss / len(test_loader), correct / len(test_loader.dataset)
# Out:
# Total trainable parameters: 128896

# %%
train_losses = []
test_losses = []

epochs = 30
for epoch in range(epochs):
    train_loss = train(model, train_loader, criterion, optimizer, device)
    test_loss, test_accuracy = validate(model, test_loader, criterion, device)

    train_losses.append(train_loss)
    test_losses.append(test_loss)
    
    print(f'Epoch {epoch + 1}, Train Loss: {train_loss:.4f}, '
          f'Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}')

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, epochs + 1), test_losses, label='Test Loss')
plt.title('Train and Test Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1, Train Loss: 1.4526, Test Loss: 0.7563, Test Acc: 0.90
# Epoch 2, Train Loss: 0.4933, Test Loss: 0.3966, Test Acc: 0.91
# Epoch 3, Train Loss: 0.2840, Test Loss: 0.2228, Test Acc: 0.95
# Epoch 4, Train Loss: 0.2222, Test Loss: 0.2129, Test Acc: 0.94
# Epoch 5, Train Loss: 0.1912, Test Loss: 0.1760, Test Acc: 0.95
# Epoch 6, Train Loss: 0.1724, Test Loss: 0.1500, Test Acc: 0.96
# Epoch 7, Train Loss: 0.1567, Test Loss: 0.1646, Test Acc: 0.95
# Epoch 8, Train Loss: 0.1470, Test Loss: 0.1441, Test Acc: 0.96
# Epoch 9, Train Loss: 0.1387, Test Loss: 0.1312, Test Acc: 0.96
# Epoch 10, Train Loss: 0.1313, Test Loss: 0.1630, Test Acc: 0.95
# Epoch 11, Train Loss: 0.1254, Test Loss: 0.1666, Test Acc: 0.95
# Epoch 12, Train Loss: 0.1203, Test Loss: 0.1451, Test Acc: 0.96
# Epoch 13, Train Loss: 0.1133, Test Loss: 0.1429, Test Acc: 0.96
# Epoch 14, Train Loss: 0.1091, Test Loss: 0.1321, Test Acc: 0.96
# Epoch 15, Train Loss: 0.1054, Test Loss: 0.1346, Test Acc: 0.96
# ...

# %% [markdown]
# ## Take a peek at what the Fibonacci Polynomials look like

# %%
def fibonacci_polynomials(x, degree):
    # Base cases for P_0(x) and P_1(x)
    if degree == 0:
        return np.zeros_like(x)
    elif degree == 1:
        return np.ones_like(x)
    
    # Initial values for P_0(x) and P_1(x)
    Pn_2 = np.zeros_like(x)  # P_0(x)
    Pn_1 = np.ones_like(x)      # P_1(x)
    Pn = None
    
    # Compute Fibonacci polynomials using the recurrence relation
    for n in range(2, degree + 1):
        Pn = (x * Pn_1 + Pn_2)
        Pn_2, Pn_1 = Pn_1, Pn  # Update values for the next iteration
    
    return Pn

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
# choose the layer u want to inspect
all_coeffs = model.fibonaccikan1.fib_coeffs.detach().cpu().numpy()
# choose the input dim
all_coeffs = all_coeffs[28 * 28 // 2]
# Plot over output dim
for some_coeffs in all_coeffs:
    x_values = np.linspace(-1, 1, 400)
    y_values = np.zeros_like(x_values)
    for i, coeff in enumerate(some_coeffs):
        y_values += coeff * fibonacci_polynomials(x_values, i)
    
    plt.plot(x_values, y_values)
    
plt.title('Function Represented by Fibonacci Coefficients')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
# choose the layer u want to inspect
all_coeffs = model.fibonaccikan2.fib_coeffs.detach().cpu().numpy()
# choose the input dim
all_coeffs = all_coeffs[16]
# Plot over output dim
for some_coeffs in all_coeffs:
    x_values = np.linspace(-1, 1, 400)
    y_values = np.zeros_like(x_values)
    for i, coeff in enumerate(some_coeffs):
        y_values += coeff * fibonacci_polynomials(x_values, i)
    
    plt.plot(x_values, y_values)
    
plt.title('Function Represented by Fibonacci Coefficients')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
# choose the layer u want to inspect
all_coeffs = model.fibonaccikan3.fib_coeffs.detach().cpu().numpy()
# choose the input dim
all_coeffs = all_coeffs[8]
# Plot over output dim
for some_coeffs in all_coeffs:
    x_values = np.linspace(-1, 1, 400)
    y_values = np.zeros_like(x_values)
    for i, coeff in enumerate(some_coeffs):
        y_values += coeff * fibonacci_polynomials(x_values, i)
    
    plt.plot(x_values, y_values)
    
plt.title('Function Represented by Fibonacci Coefficients')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
